# %% [markdown]
# <a href="https://colab.research.google.com/github/maijaviska/JS_bootcamp/blob/master/Biznesa_datu_analitika_Turiba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2 + 3
# Out:
# 5

# %%
5 * 3
# Out:
# 15

# %%
6*2
# Out:
# 12

# %% [markdown]
# # My new *Notebook*
# ## Another **Notebook**
# ### Yet another ***Notebook***
#
# This is my notebook

# %% [markdown]
# # My new notebook

# %%
2*3
# Out:
# 6

# %%
4*5
# Out:
# 20

# %% [markdown]
# # My Second Code Block

# %%
5 * 7
# Out:
# 35

# %%
7 * 9
# Out:
# 63

# %%
print("Hello")
print("Hello!")
print("Hello")
print("Hello!")
print("Hello!")
print("Hello!")
print("Hello!")
print("Hello")
# Out:
# Hello
# Hello!
# Hello
# Hello!
# Hello!
# Hello!
# Hello!
# Hello

# %%
print(8 + 7)
print(9 * 10)
3 * 2
# Out:
# 15
# 90
# 6

# %%
a = 2

# %%
b = 3

# %%
a * b
# Out:
# 6

# %%
a + 3
# Out:
# 5

# %%
a - b
# Out:
# -1
